# %%
import pandas as pd
# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("TD cryptanalyse-20200410/TextMono1917.txt", header=None)

# %%
df
# Out:
#                                                    0
# 0  MWJNJTKUPOJGKOTNOAPRKOJKWNYYKNJGNOQMVPHVAKNWHV...

# %%
type(df.iat[0,0])
# Out:
# str

# %%
words = df.iat[0,0]

# %%
words
# Out:
# '...'

# %%
type(words)
# Out:
# str

# %%
words[0]
# Out:
# 'M'

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
alphabet = alphabet.upper()
tab = {}
for l in alphabet:
    tab[l] = 0

# %%
# Calcul du nb d'occurence de chaque lettre
for letter in words:
    tab[letter] += 1
    
print(tab)
# Out:
# {'A': 125, 'B': 3, 'C': 89, 'D': 15, 'E': 0, 'F': 7, 'G': 67, 'H': 51, 'I': 19, 'J': 133, 'K': 317, 'L': 18, 'M': 148, 'N': 116, 'O': 152, 'P': 137, 'Q': 46, 'R': 7, 'S': 0, 'T': 69, 'U': 144, 'V': 126, 'W': 18, 'X': 32, 'Y': 68, 'Z': 10}

# %%
# Calcule en frequence
tabF = {}
for i in tab:
    tabF[i] = tab[i]/len(words)

# %%
a = 0
for i in tab:
    a += tab[i]
a
# Out:
# 1917

# %%
plt.figure(figsize=(12,8))
plt.bar(range(len(tabF)), list(tabF.values()), align='center')
plt.xticks(range(len(tabF)), list(tabF.keys()))
plt.show()

# %%
# Calcul des occurences de 2 lettres successives identiques

# %%
tab2id = {}
# Calcul des occurences
for i in range(0, len(words)-2):
    if (words[i] == words[i+1]):
        di = words[i] + words[i+1]
        if di in tab2id:
            tab2id[di] += 1
        else:
            tab2id[di] = 1

print(tab2id)

# Calcul des fréquences
total = 0
for i in tab2id:
    total += tab2id[i]

tab2idF = {}
for i in tab2id:
    tab2idF[i] = tab2id[i]/total
# Out:
# {'YY': 4, 'KK': 11, 'UU': 11, 'PP': 8, 'TT': 4, 'CC': 7, 'OO': 2, 'JJ': 4, 'GG': 3, 'AA': 2, 'II': 1}

# %%
plt.figure(figsize=(12,8))
plt.bar(range(len(tab2idF)), list(tab2idF.values()), align='center')
plt.xticks(range(len(tab2idF)), list(tab2idF.keys()))
plt.show()

# %%
# Calcul des digrammes

# %%
tabDi = {}
# Calcul des occurences
for i in range(0, len(words)-1):
    di = words[i] + words[i+1]
    if di in tabDi:
        tabDi[di] += 1
    else:
        tabDi[di] = 1

# Calcul des fréquences
total = 0
for i in tabDi:
    total += tabDi[i]

tabDiF = {}
for i in tabDi:
    tabDiF[i] = tabDi[i]/total
    
listDi = sorted(tabDiF.items(), key=lambda t: t[1], reverse=True)

tabDiFsorted = {}
for i in range(0,15):
    tabDiFsorted[listDi[i][0]] = listDi[i][1]
    
tabDiFsorted
# Out:
# {'KU': 0.027139874739039668,
#  'CK': 0.02139874739039666,
#  'KJ': 0.017745302713987474,
#  'NO': 0.01722338204592902,
#  'XO': 0.016701461377870562,
#  'KO': 0.016179540709812108,
#  'AK': 0.015657620041753653,
#  'JP': 0.015135699373695199,
#  'TK': 0.014091858037578288,
#  'PK': 0.014091858037578288,
#  'JK': 0.013569937369519834,
#  'YK': 0.013569937369519834,
#  'NJ': 0.013048016701461378,
#  'HK': 0.013048016701461378,
#  'QN': 0.013048016701461378}

# %%
plt.figure(figsize=(12,8))
plt.bar(range(len(tabDiFsorted)), list(tabDiFsorted.values()), align='center')
plt.xticks(range(len(tabDiFsorted)), list(tabDiFsorted.keys()))
plt.show()

# %%
# Calcul des trigrammes

# %%
tabTri = {}
# Calcul des occurences
for i in range(0, len(words)-2):
    tri = words[i] + words[i+1] + words[i+2]
    if tri in tabTri:
        tabTri[tri] += 1
    else:
        tabTri[tri] = 1

# Calcul des fréquences
total = 0
for i in tabTri:
    total += tabTri[i]

tabTriF = {}
for i in tabTri:
    tabTriF[i] = tabTri[i]/total
    
listTri = sorted(tabTriF.items(), key=lambda t: t[1], reverse=True)

tabTriFsorted = {}
for i in range(0,15):
    tabTriFsorted[listTri[i][0]] = listTri[i][1]
    
tabTriFsorted
# Out:
# {'QNO': 0.008877284595300261,
#  'NOU': 0.008877284595300261,
#  'KUP': 0.00835509138381201,
#  'XOK': 0.00835509138381201,
#  'TKU': 0.007832898172323759,
#  'KOA': 0.006266318537859008,
#  'PAK': 0.006266318537859008,
#  'KJP': 0.006266318537859008,
#  'MJP': 0.005744125326370757,
#  'VKO': 0.004699738903394256,
#  'YNJ': 0.004699738903394256,
#  'AKU': 0.004177545691906005,
#  'UVK': 0.004177545691906005,
#  'KYK': 0.004177545691906005,
#  'PKU': 0.004177545691906005}

# %%
plt.figure(figsize=(12,8))
plt.bar(range(len(tabTriFsorted)), list(tabTriFsorted.values()), align='center')
plt.xticks(range(len(tabTriFsorted)), list(tabTriFsorted.keys()))
plt.show()

# %%
# Calcul des quadrigrammes

# %%
tabTri = {}
# Calcul des occurences
for i in range(0, len(words)-3):
    tri = words[i] + words[i+1] + words[i+2] + words[i+3]
    if tri in tabTri:
        tabTri[tri] += 1
    else:
        tabTri[tri] = 1

# Calcul des fréquences
total = 0
for i in tabTri:
    total += tabTri[i]

tabTriF = {}
for i in tabTri:
    tabTriF[i] = tabTri[i]/total
    
listTri = sorted(tabTriF.items(), key=lambda t: t[1], reverse=True)

tabTriFsorted = {}
for i in range(0,15):
    tabTriFsorted[listTri[i][0]] = listTri[i][1]
    
tabTriFsorted
# Out:
# {'QNOU': 0.008359456635318705,
#  'TKUP': 0.006269592476489028,
#  'YKJP': 0.0036572622779519333,
#  'KUPO': 0.003134796238244514,
#  'UPOJ': 0.003134796238244514,
#  'YNJU': 0.003134796238244514,
#  'NJUV': 0.003134796238244514,
#  'JUVK': 0.003134796238244514,
#  'UVKO': 0.003134796238244514,
#  'VKOA': 0.003134796238244514,
#  'PPAK': 0.002612330198537095,
#  'UQNO': 0.002612330198537095,
#  'VXOK': 0.002612330198537095,
#  'KCCK': 0.002612330198537095,
#  'YMVU': 0.0020898641588296763}

# %%
plt.figure(figsize=(12,8))
plt.bar(range(len(tabTriFsorted)), list(tabTriFsorted.values()), align='center')
plt.xticks(range(len(tabTriFsorted)), list(tabTriFsorted.keys()))
plt.show()
